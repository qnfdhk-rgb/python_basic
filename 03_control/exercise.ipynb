# %%
my_teacher = 'capybara'

if my_teacher == 'capybara':
    print('우리 쌤은 카피바라 쌤입니다.')
if my_teacher == 'tiger':
    print('우리 쌤은 호랑이 쌤입니다.')
# Out:
# 우리 쌤은 카피바라 쌤입니다.

# %%
my_teacher = 'zzap_capybara'

if my_teacher == 'capybara':
    print('우리 쌤은 카피바라 쌤입니다.')
else:
    print('우리 쌤은 그럼 누구?')
# Out:
# 우리 쌤은 그럼 누구?

# %%
my_teacher = 'monkey'

if my_teacher == 'tiger':
    print('우리 쌤은 호랑이 쌤입니다.')
elif my_teacher == 'monkey':
    print('우리 쌤은 원숭이!')
else:
    print('우리 쌤은 그럼 누구?')
# Out:
# 우리 쌤은 원숭이!

# %%
print("참" if True else "거짓")
print("참" if False else "거짓")
# Out:
# 참
# 거짓

# %%
input('정수 입력 : ')
# Out:
# ''

# %%
num = int(input('정수 입력 : '))
print('홀수' if num % 2 != 0 else '짝수')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 num = int(input('정수 입력 : '))
#       2 print('홀수' if num % 2 != 0 else '짝수')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = int(input('첫 번째 정수 입력 : '))
b = int(input('두 번째 정수 입력 : '))

big = a if a > b else b
small = a if a < b else b
print(big, small)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = int(input('첫 번째 정수 입력 : '))
#       2 b = int(input('두 번째 정수 입력 : '))
#       3
#       4 big = a if a > b else b
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = int(input('첫번째 정수 입력 : '))
b = int(input('두번째 정수 입력 : '))

big = a if a > b else b
small = a if a < b else b
print(big, small)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = int(input('첫번째 정수 입력 : '))
#       2 b = int(input('두번째 정수 입력 : '))
#       3
#       4 big = a if a > b else b
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print("=== OhGiraffers vending machine ===")
print("tiger: 우리는 1인 24시간 교대제로 간다")
print("monkey: 24시간 문의 환영, 다른 말로 하면?")
print("squirrel: 저도 하루에 너다섯 시간 자는데요?")
print("capybara: 살아남는 사람이 강한 사람입니다.")
print("====================================")
print("만나고 싶은 선생님을 입력해 주세요")
input_teacher = input()
print("====================================")

sleep_time = 0
match input_teacher:
    case "tiger":
        print("호랑이 선생님의 메타버스에 오신 것을 환영합니다.")
        sleep_time = 3
    case "monkey":
        print("원숭이 선생님의 밀림에 오신 것을 환영합니다.")
        sleep_time =4
    case "squirrel":
        print("다람쥐 선생님의 매력의 늪에 오신 것을 환영합니다.")
        sleep_time = 5
    case _:
        print("공부할 마음이 없으신 건 아니죠?")

        print("매일 " + str(sleep_time) + "시간의 수면이 예상됩니다.")
# Out:
# === OhGiraffers vending machine ===
# tiger: 우리는 1인 24시간 교대제로 간다
# monkey: 24시간 문의 환영, 다른 말로 하면?
# squirrel: 저도 하루에 너다섯 시간 자는데요?
# capybara: 살아남는 사람이 강한 사람입니다.
# ====================================
# 만나고 싶은 선생님을 입력해 주세요
# ====================================
# 공부할 마음이 없으신 건 아니죠?
# 매일 0시간의 수면이 예상됩니다.

# %%
문제 1: 선택의 시작
"카피바라는 서울에 갈 것인가?"
카피바라는 서울로 상경할 계획을 세우고 있습니다. 다음 조건을 확인하세요.
사용자에게 "서울에 갈 계획이 있나요? (y/n): "를 입력받으세요.
입력값이 'y'이면 "서울로 간다!"를 출력하세요.
# Out:
#   Cell In[7], line 1
#     문제 1: 선택의 시작
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 문제 1: 선택의 시작
# "카피바라는 서울에 갈 것인가?"
# 카피바라는 서울로 상경할 계획을 세우고 있습니다. 다음 조건을 확인하세요.
# 사용자에게 "서울에 갈 계획이 있나요? (y/n): "를 입력받으세요.
# 입력값이 'y'이면 "서울로 간다!"를 출력하세요.

# %%
customers = '토끼', '곰', '여우', '호랑이'

for animals in customers:
    print(f"안녕하세요, {animals}님! 무엇을 도와드릴까요?")
# Out:
# 안녕하세요, 토끼님! 무엇을 도와드릴까요?
# 안녕하세요, 곰님! 무엇을 도와드릴까요?
# 안녕하세요, 여우님! 무엇을 도와드릴까요?
# 안녕하세요, 호랑이님! 무엇을 도와드릴까요?

# %%
orders = '아메리카노', '카페라떼', '핫초코'

for drink in orders:
    print(f"{drink}를 준비 중입니다...")
# Out:
# 아메리카노를 준비 중입니다...
# 카페라떼를 준비 중입니다...
# 핫초코를 준비 중입니다...

# %%
tables = (1, 2, 3, 4, 5)

for clearing in tables:
    print(f"[{clearing}번 테이블]청소 완료")
# Out:
# [1번 테이블]청소 완료
# [2번 테이블]청소 완료
# [3번 테이블]청소 완료
# [4번 테이블]청소 완료
# [5번 테이블]청소 완료

# %%
for time in range(9,13):
    print(f"현재 시간: [{time}]시, 근무 기록합니다")
# Out:
# 현재 시간: [9]시, 근무 기록합니다
# 현재 시간: [10]시, 근무 기록합니다
# 현재 시간: [11]시, 근무 기록합니다
# 현재 시간: [12]시, 근무 기록합니다

# %%
for number in range(1,11):
    print(f"손님 [{number}]번째 입장!")
# Out:
# 손님 [1]번째 입장!
# 손님 [2]번째 입장!
# 손님 [3]번째 입장!
# 손님 [4]번째 입장!
# 손님 [5]번째 입장!
# 손님 [6]번째 입장!
# 손님 [7]번째 입장!
# 손님 [8]번째 입장!
# 손님 [9]번째 입장!
# 손님 [10]번째 입장!

# %%
for num in range(1,6):
    print(f"[{num}]번째 커피를 만들고 있습니다.")
# Out:
# [1]번째 커피를 만들고 있습니다.
# [2]번째 커피를 만들고 있습니다.
# [3]번째 커피를 만들고 있습니다.
# [4]번째 커피를 만들고 있습니다.
# [5]번째 커피를 만들고 있습니다.

# %%
i = 1

while i <= 5:
    print(f"[{i}번 테이블] 청소 완료!")
    i += 1
# Out:
# [1번 테이블] 청소 완료!
# [2번 테이블] 청소 완료!
# [3번 테이블] 청소 완료!
# [4번 테이블] 청소 완료!
# [5번 테이블] 청소 완료!

# %%
customers = 5

while customers >= 0:
    print(f'남은 손님 수: [{customers}]명')
    customers -= 1

print(f'오늘의 영업이 끝났습니다!')
# Out:
# 남은 손님 수: [5]명
# 남은 손님 수: [4]명
# 남은 손님 수: [3]명
# 남은 손님 수: [2]명
# 남은 손님 수: [1]명
# 남은 손님 수: [0]명
# 오늘의 영업이 끝났습니다!
